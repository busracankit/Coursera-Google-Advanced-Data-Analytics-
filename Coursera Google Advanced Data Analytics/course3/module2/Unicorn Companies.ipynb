# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
companies = pd.read_csv("Unicorn_Companies.csv")

# %%
companies.head(10)
# Out:
#         Company Valuation ($B) Date Joined         Country           City  \
# 0     Bytedance           $140    4/7/2017           China        Beijing
# 1        SpaceX         $100.3   12/1/2012   United States      Hawthorne
# 2        Stripe            $95   1/23/2014   United States  San Francisco
# 3        Klarna          $45.6  12/12/2011          Sweden      Stockholm
# 4    Epic Games            $42  10/26/2018   United States           Cary
# 5         Canva            $40    1/8/2018       Australia    Surry Hills
# 6  Checkout.com            $40    5/2/2019  United Kingdom         London
# 7     Instacart            $39  12/30/2014   United States  San Francisco
# 8    Databricks            $38    2/5/2019   United States  San Francisco
# 9       Revolut            $33   4/26/2018  United Kingdom         London
#
#                               Industry  \
# 0              Artificial intelligence
# 1                                Other
# ...

# %%
companies.size
# Out:
# 13481

# %%
companies.shape
# Out:
# (1037, 13)

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1020 non-null   object
#  7   Founded Year       994 non-null    float64
#  8   Total Raised       1013 non-null   object
#  9   Financial Stage    49 non-null     object
#  10  Investors Count    1036 non-null   float64
#  11  Deal Terms         1008 non-null   float64
#  12  Portfolio Exits    49 non-null     float64
# dtypes: float64(4), object(9)
# memory usage: 105.4+ KB

# %%
companies.describe()
# Out:
#        Founded Year  Investors Count   Deal Terms  Portfolio Exits
# count    994.000000      1036.000000  1008.000000        49.000000
# mean    2012.710262        14.432432     3.093254         1.346939
# std        5.942876         9.946537     2.159764         0.751416
# min     1919.000000         1.000000     1.000000         1.000000
# 25%     2011.000000         8.000000     1.000000         1.000000
# 50%     2014.000000        13.000000     3.000000         1.000000
# 75%     2016.000000        19.000000     4.000000         1.000000
# max     2021.000000        91.000000    19.000000         5.000000

# %%
companies['Date Joined'] = pd.to_datetime(companies[ 'Date Joined' ])

# %%
companies.info
# Out:
# <bound method DataFrame.info of            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140  2017-04-07          China        Beijing
# 1           SpaceX         $100.3  2012-12-01  United States      Hawthorne
# 2           Stripe            $95  2014-01-23  United States  San Francisco
# 3           Klarna          $45.6  2011-12-12         Sweden      Stockholm
# 4       Epic Games            $42  2018-10-26  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1  2022-02-22  United States       New York
# 1033      Scalapay             $1  2022-02-23          Italy          Milan
# 1034  Omada Health             $1  2022-02-23  United States  San Francisco
# 1035    BlueVoyant             $1  2022-02-23  United States       New York
# 1036          Veev             $1  2022-02-24  United States      San Mateo
#
# ...

# %%
companies['Year Joined'] = companies['Date Joined'].dt.year

# %%
companies.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140  2017-04-07          China        Beijing
# 1      SpaceX         $100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            $95  2014-01-23  United States  San Francisco
# 3      Klarna          $45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            $42  2018-10-26  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
companies_sample = companies.sample(n =50 ,random_state =42)

# %%
companies_sample["years_till_unicorn"] = companies_sample["Year Joined"] - companies_sample["Founded Year"]


grouped = (companies_sample[["Industry", "years_till_unicorn"]]
           .groupby("Industry")
           .max()
           .sort_values(by="years_till_unicorn")
          )
grouped
# Out:
#                                                     years_till_unicorn
# Industry
# Andreessen Horowitz, DST Global, IDG Capital                       1.0
# Sequoia Capital, Thoma Bravo, Softbank                             3.0
# Sequoia Capital China, ING, Alibaba Entrepreneu...                 4.0
# Hardware                                                           4.0
# Auto & transportation                                              5.0
# Other                                                              5.0
# Cybersecurity                                                      7.0
# Artificial intelligence                                            7.0
# Health                                                            10.0
# Sequoia Capital China, Shunwei Capital Partners...                14.0
# E-commerce & direct-to-consumer                                   15.0
# Data management & analytics                                       16.0
# ...

# %%
plt.bar(grouped.index, grouped["years_till_unicorn"])

plt.title("Bar plot of maximum years taken by company to become unicorn per industry (from sample)")

plt.xlabel("Industry")

plt.ylabel("Maximum number of years")

plt.xticks(rotation=45, horizontalalignment='right')

plt.show()

# %%
companies_sample['valuation_billions'] = companies_sample['Valuation ($B)'] # Replacing 'Valuation' with 'Valuation ($B)'
companies_sample['valuation_billions'] = companies_sample['valuation_billions'].str.replace('$', '')
companies_sample['valuation_billions'] = companies_sample['valuation_billions'].str.replace('B', '')
# Changed to astype(float) instead of astype(int) to handle decimal values.
companies_sample['valuation_billions'] = companies_sample['valuation_billions'].astype('float')

companies_sample.head()
# Out:
#                  Company Valuation ($B) Date Joined         Country  \
# 622  DeepBlue Technology          $1.35  2018-04-16           China
# 109              Lianjia          $5.77  2016-04-07           China
# 649             YugaByte           $1.3  2021-10-28   United States
# 458        Starling Bank          $1.95  2021-03-08  United Kingdom
# 541              Uplight           $1.5  2021-03-03   United States
#
#           City                         Industry  \
# 622   Shanghai          Artificial intelligence
# 109    Beijing  E-commerce & direct-to-consumer
# 649  Sunnyvale      Data management & analytics
# 458     London                          Fintech
# 541    Boulder                            Other
#
#                                      Select Inverstors  Founded Year  \
# 622   DESUN Capital, Yunfeng Capital, Meridian Capital        2014.0
# 109                   Tencent, Baidu, Huasheng Capital        2001.0
# ...

# %%
grouped =(companies_sample[["Industry","valuation_billions"]]
          .groupby("Industry")
          .max()
          .sort_values(by="valuation_billions")
         )
grouped
# Out:
#                                                     valuation_billions
# Industry
# Andreessen Horowitz, DST Global, IDG Capital                      1.00
# Sequoia Capital China, Shunwei Capital Partners...                1.00
# Sequoia Capital China, ING, Alibaba Entrepreneu...                1.00
# Auto & transportation                                             1.44
# Other                                                             1.50
# Supply chain, logistics, & delivery                               2.20
# Artificial intelligence                                           2.92
# Data management & analytics                                       3.60
# Mobile & telecommunications                                       3.80
# E-commerce & direct-to-consumer                                   5.77
# Hardware                                                          6.00
# Internet software & services                                      6.30
# ...

# %%
plt.bar(grouped.index, grouped["valuation_billions"])

plt.title("Bar plot of maximum years taken by company to become unicorn per industry (from sample)")

plt.xlabel("Industry")

plt.ylabel("Maximum valuation in billions of dollars")

plt.xticks(rotation=45, horizontalalignment='right')

plt.show()
